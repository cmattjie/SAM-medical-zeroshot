# %%
import os
import nibabel as nib
import imageio
import numpy as np

def normalize_image(img, min_val, max_val):
    img[img < min_val] = min_val
    img[img > max_val] = max_val
    return (img - min_val) / (max_val - min_val)

def convert_nii_to_png(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(".nii") or filename.endswith(".nii.gz"):
            file_path = os.path.join(input_folder, filename)
            img_nii = nib.load(file_path)
            img_data = img_nii.get_fdata()

            # Assuming the images are 2D, find the default window level values
            min_val = np.min(img_data)
            max_val = np.max(img_data)

            # Normalize the image using the default window level values
            img_normalized = normalize_image(img_data, min_val, max_val)

            # Save the image as a PNG file
            output_filename = os.path.splitext(filename)[0] + ".png"
            output_path = os.path.join(output_folder, output_filename)
            imageio.imwrite(output_path, (img_normalized * 255).astype(np.uint8))

            print(f"Converted {filename} to {output_filename}")

# %%
input_folder = "/mnt/B-SSD/maltamed/datasets/2D/hip/mask"
output_folder = "/mnt/B-SSD/maltamed/datasets/2D/hip/mask"
convert_nii_to_png(input_folder, output_folder)
# Out:
# Converted label_139.nii to label_139.png
# Converted label_086.nii to label_086.png
# Converted label_044.nii to label_044.png
# Converted label_028.nii to label_028.png
# Converted label_131.nii to label_131.png
# Converted label_100.nii to label_100.png
# Converted label_029.nii to label_029.png
# Converted label_020.nii to label_020.png
# Converted label_075.nii to label_075.png
# Converted label_016.nii to label_016.png
# Converted label_018.nii to label_018.png
# Converted label_137.nii to label_137.png
# Converted label_056.nii to label_056.png
# Converted label_037.nii to label_037.png
# Converted label_058.nii to label_058.png
# Converted label_014.nii to label_014.png
# Converted label_070.nii to label_070.png
# Converted label_063.nii to label_063.png
# Converted label_011.nii to label_011.png
# Converted label_119.nii to label_119.png
# Converted label_101.nii to label_101.png
# Converted label_088.nii to label_088.png
# Converted label_097.nii to label_097.png
# Converted label_046.nii to label_046.png
# Converted label_111.nii to label_111.png
# Converted label_098.nii to label_098.png
# Converted label_106.nii to label_106.png
# Converted label_027.nii to label_027.png
# Converted label_083.nii to label_083.png
# Converted label_123.nii to label_123.png
# Converted label_109.nii to label_109.png
# Converted label_061.nii to label_061.png
# Converted label_094.nii to label_094.png
# Converted label_022.nii to label_022.png
# Converted label_059.nii to label_059.png
# Converted label_047.nii to label_047.png
# Converted label_010.nii to label_010.png
# Converted label_117.nii to label_117.png
# Converted label_004.nii to label_004.png
# Converted label_099.nii to label_099.png
# Converted label_021.nii to label_021.png
# Converted label_060.nii to label_060.png
# Converted label_002.nii to label_002.png
# Converted label_140.nii to label_140.png
# Converted label_040.nii to label_040.png
# Converted label_138.nii to label_138.png
# Converted label_113.nii to label_113.png
# Converted label_074.nii to label_074.png
# Converted label_038.nii to label_038.png
# Converted label_135.nii to label_135.png
# Converted label_118.nii to label_118.png
# Converted label_126.nii to label_126.png
# Converted label_057.nii to label_057.png
# Converted label_103.nii to label_103.png
# Converted label_013.nii to label_013.png
# Converted label_079.nii to label_079.png
# Converted label_051.nii to label_051.png
# Converted label_108.nii to label_108.png
# Converted label_124.nii to label_124.png
# Converted label_128.nii to label_128.png
# Converted label_025.nii to label_025.png
# Converted label_081.nii to label_081.png
# Converted label_005.nii to label_005.png
# Converted label_080.nii to label_080.png
# Converted label_125.nii to label_125.png
# Converted label_052.nii to label_052.png
# Converted label_129.nii to label_129.png
# Converted label_054.nii to label_054.png
# Converted label_073.nii to label_073.png
# Converted label_019.nii to label_019.png
# Converted label_001.nii to label_001.png
# Converted label_039.nii to label_039.png
# Converted label_065.nii to label_065.png
# Converted label_023.nii to label_023.png
# Converted label_034.nii to label_034.png
# Converted label_066.nii to label_066.png
# Converted label_102.nii to label_102.png
# Converted label_087.nii to label_087.png
# Converted label_095.nii to label_095.png
# Converted label_091.nii to label_091.png
# Converted label_120.nii to label_120.png
# Converted label_041.nii to label_041.png
# Converted label_036.nii to label_036.png
# Converted label_112.nii to label_112.png
# Converted label_068.nii to label_068.png
# Converted label_134.nii to label_134.png
# Converted label_031.nii to label_031.png
# Converted label_017.nii to label_017.png
# Converted label_133.nii to label_133.png
# Converted label_104.nii to label_104.png
# Converted label_064.nii to label_064.png
# Converted label_136.nii to label_136.png
# Converted label_089.nii to label_089.png
# Converted label_026.nii to label_026.png
# Converted label_055.nii to label_055.png
# Converted label_012.nii to label_012.png
# Converted label_045.nii to label_045.png
# Converted label_085.nii to label_085.png
# Converted label_082.nii to label_082.png
# Converted label_062.nii to label_062.png
# Converted label_033.nii to label_033.png
# Converted label_067.nii to label_067.png
# Converted label_116.nii to label_116.png
# Converted label_077.nii to label_077.png
# Converted label_007.nii to label_007.png
# Converted label_096.nii to label_096.png
# Converted label_105.nii to label_105.png
# Converted label_093.nii to label_093.png
# Converted label_015.nii to label_015.png
# Converted label_078.nii to label_078.png
# Converted label_110.nii to label_110.png
# Converted label_043.nii to label_043.png
# Converted label_130.nii to label_130.png
# Converted label_127.nii to label_127.png
# Converted label_032.nii to label_032.png
# Converted label_122.nii to label_122.png
# Converted label_009.nii to label_009.png
# Converted label_114.nii to label_114.png
# Converted label_024.nii to label_024.png
# Converted label_049.nii to label_049.png
# Converted label_121.nii to label_121.png
# Converted label_053.nii to label_053.png
# Converted label_030.nii to label_030.png
# Converted label_115.nii to label_115.png
# Converted label_107.nii to label_107.png
# Converted label_069.nii to label_069.png
# Converted label_050.nii to label_050.png
# Converted label_048.nii to label_048.png
# Converted label_132.nii to label_132.png
# Converted label_035.nii to label_035.png
# Converted label_092.nii to label_092.png
# Converted label_006.nii to label_006.png
# Converted label_076.nii to label_076.png
# Converted label_042.nii to label_042.png
# Converted label_090.nii to label_090.png
# Converted label_008.nii to label_008.png
# Converted label_071.nii to label_071.png
# Converted label_003.nii to label_003.png
# Converted label_084.nii to label_084.png
# Converted label_072.nii to label_072.png
